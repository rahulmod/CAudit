# %% [markdown]
# # Advertising Analytics Click Prediction: ML
# ####[Ad impressions with clicks dataset](https://www.kaggle.com/c/avazu-ctr-prediction/data)
#
# <img src="/files/img/fraud_ml_pipeline.png" alt="workflow" width="500">
#
# This is the ML notebook for the series of Advertising Analytics Click Prediction notebooks.  For this stage, we will focus on creating features and training and evaluating the ML model.
#
# <img src="https://s3-us-west-2.amazonaws.com/pub-tc/ML-workflow.png" width="800">

# %%
impression = spark.read \
  .parquet("/mnt/adtech/impression/parquet/train.csv/") \
  .selectExpr("*", "substr(hour, 7) as hr").repartition(64)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import *

strCols = map(lambda t: t[0], filter(lambda t: t[1] == 'string', impression.dtypes))
intCols = map(lambda t: t[0], filter(lambda t: t[1] == 'int', impression.dtypes))

# [row_idx][json_idx]
strColsCount = sorted(map(lambda c: (c, impression.select(countDistinct(c)).collect()[0][0]), strCols), key=lambda x: x[1], reverse=True)
intColsCount = sorted(map(lambda c: (c, impression.select(countDistinct(c)).collect()[0][0]), intCols), key=lambda x: x[1], reverse=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# distinct counts for str columns
display(strColsCount)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_1</th><th>_2</th></tr></thead><tbody><tr><td>device_ip</td><td>6729486</td></tr><tr><td>device_id</td><td>2686408</td></tr><tr><td>app_id</td><td>8552</td></tr><tr><td>device_model</td><td>8251</td></tr><tr><td>site_domain</td><td>7745</td></tr><tr><td>site_id</td><td>4737</td></tr><tr><td>app_domain</td><td>559</td></tr><tr><td>app_category</td><td>36</td></tr><tr><td>site_category</td><td>26</td></tr><tr><td>hr</td><td>24</td></tr></tbody></table></div>

# %%
# distinct counts for int columns
display(intColsCount)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_1</th><th>_2</th></tr></thead><tbody><tr><td>C14</td><td>2626</td></tr><tr><td>C17</td><td>435</td></tr><tr><td>hour</td><td>240</td></tr><tr><td>C20</td><td>172</td></tr><tr><td>C19</td><td>68</td></tr><tr><td>C21</td><td>60</td></tr><tr><td>C16</td><td>9</td></tr><tr><td>C15</td><td>8</td></tr><tr><td>C1</td><td>7</td></tr><tr><td>banner_pos</td><td>7</td></tr><tr><td>device_type</td><td>5</td></tr><tr><td>device_conn_type</td><td>4</td></tr><tr><td>C18</td><td>4</td></tr><tr><td>click</td><td>2</td></tr></tbody></table></div>

# %%
# Include PySpark Feature Engineering methods
from pyspark.ml.feature import StringIndexer, VectorAssembler

# All of the columns (string or integer) are categorical columns
#  except for the [click] column
maxBins = 70
categorical = map(lambda c: c[0], filter(lambda c: c[1] <= maxBins, strColsCount))
categorical += map(lambda c: c[0], filter(lambda c: c[1] <= maxBins, intColsCount))
categorical.remove('click')

# Apply string indexer to all of the categorical columns
#  And add _idx to the column name to indicate the index of the categorical value
stringIndexers = map(lambda c: StringIndexer(inputCol = c, outputCol = c + "_idx"), categorical)

# Assemble the put as the input to the VectorAssembler 
#   with the output being our features
assemblerInputs = map(lambda c: c + "_idx", categorical)
vectorAssembler = VectorAssembler(inputCols = assemblerInputs, outputCol = "features")

# The [click] column is our label 
labelStringIndexer = StringIndexer(inputCol = "click", outputCol = "label")

# The stages of our ML pipeline 
stages = stringIndexers + [vectorAssembler, labelStringIndexer]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml import Pipeline

# Create our pipeline
pipeline = Pipeline(stages = stages)

# create transformer to add features
featurizer = pipeline.fit(impression)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# dataframe with feature and intermediate transformation columns appended
featurizedImpressions = featurizer.transform(impression)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(featurizedImpressions.select('features', 'label'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>features</th><th>label</th></tr></thead><tbody><tr><td>List(0, 12, List(1, 2, 3, 11), List(2.0, 1.0, 1.0, 1.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 11), List(2.0, 1.0, 1.0, 1.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 11), List(2.0, 1.0, 1.0, 1.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 11), List(2.0, 1.0, 1.0, 1.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(0, 2, 5, 6, 10, 11), List(1.0, 8.0, 1.0, 1.0, 1.0, 2.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 5, 6, 11), List(3.0, 5.0, 1.0, 1.0, 1.0, 1.0))</td><td>1.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 5, 6, 11), List(3.0, 5.0, 1.0, 1.0, 1.0, 1.0))</td><td>1.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 5, 6, 11), List(3.0, 5.0, 1.0, 1.0, 1.0, 1.0))</td><td>1.0</td></tr><tr><td>List(0, 12, List(0, 2, 3, 4, 10, 11), List(3.0, 11.0, 26.0, 11.0, 1.0, 3.0))</td><td>1.0</td></tr><tr><td>List(0, 12, List(0, 2, 3, 4, 11), List(2.0, 16.0, 17.0, 12.0, 1.0))</td><td>1.0</td></tr><tr><td>List(0, 12, List(0, 2, 3, 4, 11), List(2.0, 16.0, 17.0, 12.0, 1.0))</td><td>1.0</td></tr><tr><td>List(0, 12, List(0, 2, 3, 4, 11), List(2.0, 16.0, 17.0, 12.0, 1.0))</td><td>1.0</td></tr><tr><td>List(0, 12, List(0, 2, 3, 4, 11), List(2.0, 16.0, 17.0, 12.0, 1.0))</td><td>1.0</td></tr><tr><td>List(0, 12, List(0, 2, 4, 11), List(1.0, 20.0, 7.0, 2.0))</td><td>1.0</td></tr><tr><td>List(0, 12, List(0, 2, 3, 4, 10, 11), List(4.0, 12.0, 17.0, 12.0, 1.0, 1.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(0, 2, 3, 4, 11), List(2.0, 11.0, 22.0, 5.0, 1.0))</td><td>1.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 4, 11), List(1.0, 10.0, 1.0, 7.0, 2.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 4, 11), List(1.0, 10.0, 1.0, 7.0, 2.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 4, 11), List(1.0, 10.0, 1.0, 7.0, 2.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 4, 11), List(1.0, 10.0, 1.0, 7.0, 2.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 4, 11), List(1.0, 10.0, 1.0, 7.0, 2.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 4, 11), List(1.0, 10.0, 1.0, 7.0, 2.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 4, 11), List(1.0, 10.0, 1.0, 7.0, 2.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 4, 11), List(1.0, 10.0, 1.0, 7.0, 2.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 4, 11), List(1.0, 10.0, 1.0, 7.0, 2.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 4, 11), List(1.0, 10.0, 1.0, 7.0, 2.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 4, 11), List(1.0, 10.0, 1.0, 7.0, 2.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 4, 11), List(1.0, 10.0, 1.0, 7.0, 2.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 4, 11), List(1.0, 10.0, 1.0, 7.0, 2.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 4, 11), List(1.0, 10.0, 1.0, 7.0, 2.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 4, 11), List(1.0, 10.0, 1.0, 7.0, 2.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 4, 11), List(1.0, 10.0, 1.0, 7.0, 2.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 4, 11), List(1.0, 10.0, 1.0, 7.0, 2.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 3, 4, 11), List(1.0, 10.0, 1.0, 7.0, 2.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(0, 2, 3, 4, 11), List(3.0, 1.0, 1.0, 7.0, 2.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(0, 2, 3, 4, 11), List(3.0, 1.0, 1.0, 7.0, 2.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(0, 2, 3, 4, 11), List(3.0, 1.0, 1.0, 7.0, 2.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 4, 8), List(1.0, 2.0, 2.0, 1.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 4, 8), List(1.0, 2.0, 2.0, 1.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 4, 8), List(1.0, 2.0, 2.0, 1.0))</td><td>0.0</td></tr><tr><td>List(0, 12, List(1, 2, 4, 8), List(1.0, 2.0 ...

# %%
train, test = featurizedImpressions \
  .select(["label", "features", "hr"]) \
  .randomSplit([0.7, 0.3], 42)
train.cache()
test.cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">9</span><span class="ansired">]: </span>DataFrame[label: double, features: vector, hr: string]
# </div>

# %%
from pyspark.ml.classification import GBTClassifier

# Train our GBTClassifier model 
classifier = GBTClassifier(labelCol="label", featuresCol="features", maxBins=maxBins, maxDepth=10, maxIter=10)
model = classifier.fit(train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Execute our predictions
predictions = model.transform(test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator

# Evaluate our GBTClassifier model using BinaryClassificationEvaluator()
ev = BinaryClassificationEvaluator(rawPredictionCol="rawPrediction", metricName="areaUnderROC")
print ev.evaluate(predictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0.711202645458
# </div>

# %%
import json
features = map(lambda c: str(json.loads(json.dumps(c))['name']), \
               predictions.schema['features'].metadata.get('ml_attr').get('attrs').values()[0])
# convert numpy.float64 to str for spark.createDataFrame()
weights=map(lambda w: '%.10f' % w, model.featureImportances)
weightedFeatures = sorted(zip(weights, features), key=lambda x: x[1], reverse=True)
spark.createDataFrame(weightedFeatures).toDF("weight", "feature").createOrReplaceTempView('wf')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql 
select feature, weight 
from wf 
order by weight desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>feature</th><th>weight</th></tr></thead><tbody><tr><td>C21_idx</td><td>0.4421319127</td></tr><tr><td>C19_idx</td><td>0.1150903324</td></tr><tr><td>site_category_idx</td><td>0.0946446858</td></tr><tr><td>app_category_idx</td><td>0.0851794287</td></tr><tr><td>hr_idx</td><td>0.0747225775</td></tr><tr><td>banner_pos_idx</td><td>0.0494653844</td></tr><tr><td>C18_idx</td><td>0.0457166715</td></tr><tr><td>C16_idx</td><td>0.0370146512</td></tr><tr><td>device_conn_type_idx</td><td>0.0241333606</td></tr><tr><td>C1_idx</td><td>0.0206914316</td></tr><tr><td>C15_idx</td><td>0.0081466717</td></tr><tr><td>device_type_idx</td><td>0.0030628918</td></tr></tbody></table></div>

# %%
predictions.createOrReplaceTempView("predictions")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql describe predictions
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>label</td><td>double</td><td>null</td></tr><tr><td>features</td><td>vector</td><td>null</td></tr><tr><td>hr</td><td>string</td><td>null</td></tr><tr><td>rawPrediction</td><td>vector</td><td>null</td></tr><tr><td>probability</td><td>vector</td><td>null</td></tr><tr><td>prediction</td><td>double</td><td>null</td></tr></tbody></table></div>

# %%
# %sql select sum(case when prediction = label then 1 else 0 end) / (count(1) * 1.0) as accuracy
from predictions
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>accuracy</th></tr></thead><tbody><tr><td>0.8328162140172459</td></tr></tbody></table></div>
